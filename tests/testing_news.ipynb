# %%
import requests
import pandas as pd 

url = "https://newsapi.org/v2/everything"
params = {
    "q": "news",  # generic query to get "everything"
    "apiKey": "7868055a3d6649cfa32a8561f9011b92"
}

response = requests.get(url, params=params)
data = response.json()

for article in data["articles"]:
    print(article["title"], "-", article["source"]["name"])

print(data)
# Out:
# All the news from Nintendo’s August Indie World showcase - The Verge
# All the news from Gamescom Opening Night Live 2025 - The Verge
# Truth Social’s new AI search engine basically just pushes Fox News - The Verge
# Google is adding a new way to personalize the news you see - The Verge
# Gear News of the Week: A New Privacy Phone Arrives, and Samsung Has a $30K 115-Inch Micro RGB TV - Wired
# Now That Google Is Trash, It Will Let You Pick Your Own News Sources - Gizmodo.com
# WhatsApp Just Patched a ‘Zero Click’ Bug Being Used to Hack Apple Users - Gizmodo.com
# Google Search introduces feature for prioritizing trusted news sources - Android Central
# Russell T Davies Wants You to Stop Asking Him If ‘Doctor Who’ Is Dead or Not - Gizmodo.com
# Live Updates From IFA 2025 in Berlin  - Gizmodo.com
# Peek Inside the ‘Fallout’ Vault at Universal Studios’ Halloween Horror Nights Hollywood - Gizmodo.com
# Ronaldo engaged to long-term partner Georgina Rodríguez - BBC News
# ...
